# %%
import xgboost as xgb
import xarray as xr
import pandas as pd
import numpy as np
import gc
from flaml import AutoML
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import logging 
import pickle
# logging.disable(logging.CRITICAL)
import shap
from tqdm import tqdm

# %%
model_path = ""
data_path_prefix = "" 
p_dict = {"a":model_path+"all_gridcell/", 
          "c":model_path+"clusters/",
          "r":model_path+"regions/"}

def load_model(spatial_scale,time_scale,gas_flag,loc):
    if spatial_scale == "r":
        p = p_dict[spatial_scale]+time_scale+"_aod_emission_met"+gas_flag+"_"+loc+".pkl"
    else:
        p = p_dict[spatial_scale]+time_scale+"_aod_emission_met"+gas_flag+".pkl"

    with open(p, 'rb') as f:
        # The protocol version used is detected automatically, so we do not
        # have to specify it.
        automl = pickle.load(f)
        model_name =  automl._best_estimator
    return automl, model_name

def get_feature_list(time_scale,gas_flag):
    aod_ls = ['AOT_C', 'AOT_DUST_C']
    met_ls = ['T2M', 'PBLH', 'U10M', 'V10M', 'PRECTOT', 'RH']
    gas_ls = ['CO_trop', 'SO2_trop', 'NO2_trop', 'CH2O_trop', 'NH3_trop']

    # select based on time scale
    if time_scale == "monthly":
        emission = ['EmisDST_Natural', 
                    'EmisNO_Fert', 'EmisNO_Lightning', 'EmisNO_Ship', 'EmisNO_Soil',
                    'EmisBC_Anthro', 'EmisBC_BioBurn', 
                    'EmisCH2O_Anthro', 'EmisCH2O_BioBurn', 
                    'EmisCO_Anthro', 'EmisCO_BioBurn', 'EmisCO_Ship', 
                    'EmisNH3_Anthro', 'EmisNH3_BioBurn', 'EmisNH3_Natural', 
                    'EmisNO_Aircraft', 'EmisNO_Anthro', 'EmisNO_BioBurn', 
                    'EmisOC_Anthro', 'EmisOC_BioBurn',  
                    'EmisSO2_Aircraft', 'EmisSO2_Anthro', 'EmisSO2_BioBurn',
                    'EmisSO4_Anthro']
        
         # select based on gas or not
        if gas_flag=="_gas":
            return aod_ls+emission+met_ls+gas_ls
        else:
            return aod_ls+emission+met_ls

    else:
        emission = ['EmisDST_Natural', 
                    'EmisNO_Fert', 'EmisNO_Lightning', 'EmisNO_Ship', 'EmisNO_Soil']
        if gas_flag=="_gas":
            return aod_ls+emission+met_ls+gas_ls
        else:
            return aod_ls+emission+met_ls

def load_data(spatial_scale,time_scale,gas_flag,loc,data_type):
    # get feature list and include label
    feature_ls = get_feature_list(time_scale,gas_flag)
    # select based on spatial_scale
    if spatial_scale =="r":
        if time_scale=="monthly_le":
            data_path = data_path_prefix+"c_r_monthly_"+data_type+".gzip"
        else:
            data_path = data_path_prefix+"c_r_"+time_scale+"_"+data_type+".gzip"
        df = pd.read_parquet(data_path)[feature_ls+["PM25","region"]]
        return df[df["region"]==loc], feature_ls
    elif spatial_scale == "c":
        if time_scale=="monthly_le":
            data_path = data_path_prefix+"c_r_monthly_"+data_type+".gzip"
        else:
            data_path = data_path_prefix+"c_r_"+time_scale+"_"+data_type+".gzip"
        df = pd.read_parquet(data_path)[feature_ls+["PM25"]]
        return df, feature_ls
    else:
        if time_scale=="monthly_le":
            data_path = data_path_prefix+"monthly_"+data_type+".gzip"
        else:
            data_path = data_path_prefix+time_scale+"_"+data_type+".gzip"
        df = pd.read_parquet(data_path)[feature_ls+["PM25"]]
        return df, feature_ls
    
def model_performance(df, model, feature_ls, spatial_scale):
    y_true = df["PM25"]
    y_pred = model.predict(df[feature_ls])
    r2 = round(r2_score(y_true, y_pred),3)
    rmse = round(mean_squared_error(y_true, y_pred, squared = False),3)
    mae = round(mean_absolute_error(y_true, y_pred),3)
    print(spatial_scale, "r2_score:",
          r2)
    print(spatial_scale, "root mean_squared_error:",
          rmse)
    print(spatial_scale, "mean_absolute_error:",
          mae)
    return r2, rmse, mae

# %% [markdown]
# ## save data

# %%
loc_ls = []
time_scale_ls = []
spatial_scale_ls = []
gas_ls = []
r2_ls = []
rmse_ls = []
mae_ls = []
for loc in ["E","S","W","N"]:
    print("============================")
    print("start location:",loc,"\n")
    for time_scale in ["daily","monthly_le","monthly"]:
        print("===",time_scale,"===")
        print("#########")
        for gas_flag in ["_gas",""]:
            print("##gas_flag:",gas_flag)
            spatial_scale = "r"
            df, feature_ls = load_data(spatial_scale,time_scale,gas_flag,loc,"test")
            
            for spatial_scale in ["r","a","c"]:
                print("**spatial scale:", spatial_scale)
                model, model_name = load_model(spatial_scale,time_scale,gas_flag,loc)
                r2, rmse, mae = model_performance(df, model, feature_ls, spatial_scale)
                loc_ls.append(loc)
                time_scale_ls.append(time_scale)
                spatial_scale_ls.append(spatial_scale)
                gas_ls.append(gas_flag)
                r2_ls.append(r2)
                rmse_ls.append(rmse)
                mae_ls.append(mae)
                del model, r2, rmse, mae
                gc.collect()
            
            del df
            gc.collect()
    print("============================")
# Out:
# ============================
# start location: E
#
# === daily ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.744
# r root mean_squared_error: 4.837
# r mean_absolute_error: 3.571
# **spatial scale: a
# a r2_score: 0.744
# a root mean_squared_error: 4.841
# a mean_absolute_error: 3.549
# **spatial scale: c
# c r2_score: 0.776
# c root mean_squared_error: 4.521
# c mean_absolute_error: 3.336
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.592
# r root mean_squared_error: 6.111
# r mean_absolute_error: 4.295
# **spatial scale: a
# a r2_score: 0.649
# a root mean_squared_error: 5.668
# a mean_absolute_error: 4.137
# **spatial scale: c
# c r2_score: 0.641
# c root mean_squared_error: 5.726
# c mean_absolute_error: 4.124
# === monthly_le ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.848
# r root mean_squared_error: 2.977
# r mean_absolute_error: 2.186
# **spatial scale: a
# a r2_score: 0.863
# a root mean_squared_error: 2.83
# a mean_absolute_error: 2.064
# **spatial scale: c
# c r2_score: 0.918
# c root mean_squared_error: 2.191
# c mean_absolute_error: 1.648
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.61
# r root mean_squared_error: 4.774
# r mean_absolute_error: 3.055
# **spatial scale: a
# a r2_score: 0.725
# a root mean_squared_error: 4.009
# a mean_absolute_error: 3.018
# **spatial scale: c
# c r2_score: 0.737
# c root mean_squared_error: 3.921
# c mean_absolute_error: 2.86
# === monthly ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.926
# r root mean_squared_error: 2.072
# r mean_absolute_error: 1.541
# **spatial scale: a
# a r2_score: 0.909
# a root mean_squared_error: 2.3
# a mean_absolute_error: 1.766
# **spatial scale: c
# c r2_score: 0.936
# c root mean_squared_error: 1.936
# c mean_absolute_error: 1.479
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.756
# r root mean_squared_error: 3.771
# r mean_absolute_error: 2.576
# **spatial scale: a
# a r2_score: 0.784
# a root mean_squared_error: 3.55
# a mean_absolute_error: 2.509
# **spatial scale: c
# c r2_score: 0.901
# c root mean_squared_error: 2.402
# c mean_absolute_error: 1.823
# ============================
# ============================
# start location: S
#
# === daily ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.718
# r root mean_squared_error: 3.711
# r mean_absolute_error: 2.853
# **spatial scale: a
# a r2_score: 0.672
# a root mean_squared_error: 4.005
# a mean_absolute_error: 3.124
# **spatial scale: c
# c r2_score: 0.709
# c root mean_squared_error: 3.767
# c mean_absolute_error: 2.952
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.607
# r root mean_squared_error: 4.384
# r mean_absolute_error: 3.368
# **spatial scale: a
# a r2_score: 0.6
# a root mean_squared_error: 4.419
# a mean_absolute_error: 3.403
# **spatial scale: c
# c r2_score: 0.551
# c root mean_squared_error: 4.682
# c mean_absolute_error: 3.591
# === monthly_le ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.565
# r root mean_squared_error: 3.062
# r mean_absolute_error: 2.438
# **spatial scale: a
# a r2_score: 0.482
# a root mean_squared_error: 3.34
# a mean_absolute_error: 2.696
# **spatial scale: c
# c r2_score: 0.679
# c root mean_squared_error: 2.631
# c mean_absolute_error: 2.145
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.445
# r root mean_squared_error: 3.457
# r mean_absolute_error: 2.834
# **spatial scale: a
# a r2_score: 0.563
# a root mean_squared_error: 3.069
# a mean_absolute_error: 2.461
# **spatial scale: c
# c r2_score: 0.56
# c root mean_squared_error: 3.079
# c mean_absolute_error: 2.452
# === monthly ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.625
# r root mean_squared_error: 2.841
# r mean_absolute_error: 2.243
# **spatial scale: a
# a r2_score: 0.584
# a root mean_squared_error: 2.995
# a mean_absolute_error: 2.293
# **spatial scale: c
# c r2_score: 0.698
# c root mean_squared_error: 2.553
# c mean_absolute_error: 2.143
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.586
# r root mean_squared_error: 2.987
# r mean_absolute_error: 2.502
# **spatial scale: a
# a r2_score: 0.558
# a root mean_squared_error: 3.087
# a mean_absolute_error: 2.443
# **spatial scale: c
# c r2_score: 0.538
# c root mean_squared_error: 3.156
# c mean_absolute_error: 2.49
# ============================
# ============================
# start location: W
#
# === daily ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.715
# r root mean_squared_error: 5.604
# r mean_absolute_error: 3.813
# **spatial scale: a
# a r2_score: 0.719
# a root mean_squared_error: 5.565
# a mean_absolute_error: 3.934
# **spatial scale: c
# c r2_score: 0.739
# c root mean_squared_error: 5.365
# c mean_absolute_error: 3.767
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.637
# r root mean_squared_error: 6.327
# r mean_absolute_error: 4.368
# **spatial scale: a
# a r2_score: 0.674
# a root mean_squared_error: 5.989
# a mean_absolute_error: 4.172
# **spatial scale: c
# c r2_score: 0.652
# c root mean_squared_error: 6.186
# c mean_absolute_error: 4.425
# === monthly_le ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.724
# r root mean_squared_error: 3.522
# r mean_absolute_error: 2.786
# **spatial scale: a
# a r2_score: 0.64
# a root mean_squared_error: 4.017
# a mean_absolute_error: 2.927
# **spatial scale: c
# c r2_score: 0.447
# c root mean_squared_error: 4.98
# c mean_absolute_error: 4.2
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.583
# r root mean_squared_error: 4.328
# r mean_absolute_error: 3.281
# **spatial scale: a
# a r2_score: 0.392
# a root mean_squared_error: 5.222
# a mean_absolute_error: 4.22
# **spatial scale: c
# c r2_score: 0.161
# c root mean_squared_error: 6.138
# c mean_absolute_error: 5.07
# === monthly ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.865
# r root mean_squared_error: 2.461
# r mean_absolute_error: 1.958
# **spatial scale: a
# a r2_score: 0.806
# a root mean_squared_error: 2.952
# a mean_absolute_error: 2.3
# **spatial scale: c
# c r2_score: 0.736
# c root mean_squared_error: 3.443
# c mean_absolute_error: 2.787
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.861
# r root mean_squared_error: 2.496
# r mean_absolute_error: 1.811
# **spatial scale: a
# a r2_score: 0.705
# a root mean_squared_error: 3.639
# a mean_absolute_error: 2.876
# **spatial scale: c
# c r2_score: 0.693
# c root mean_squared_error: 3.71
# c mean_absolute_error: 3.019
# ============================
# ============================
# start location: N
#
# === daily ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.782
# r root mean_squared_error: 5.863
# r mean_absolute_error: 4.137
# **spatial scale: a
# a r2_score: 0.769
# a root mean_squared_error: 6.042
# a mean_absolute_error: 4.212
# **spatial scale: c
# c r2_score: 0.792
# c root mean_squared_error: 5.733
# c mean_absolute_error: 3.989
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.72
# r root mean_squared_error: 6.645
# r mean_absolute_error: 4.695
# **spatial scale: a
# a r2_score: 0.723
# a root mean_squared_error: 6.616
# a mean_absolute_error: 4.599
# **spatial scale: c
# c r2_score: 0.703
# c root mean_squared_error: 6.845
# c mean_absolute_error: 4.83
# === monthly_le ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.722
# r root mean_squared_error: 4.907
# r mean_absolute_error: 3.719
# **spatial scale: a
# a r2_score: 0.86
# a root mean_squared_error: 3.485
# a mean_absolute_error: 2.596
# **spatial scale: c
# c r2_score: 0.806
# c root mean_squared_error: 4.1
# c mean_absolute_error: 3.244
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.341
# r root mean_squared_error: 7.559
# r mean_absolute_error: 5.569
# **spatial scale: a
# a r2_score: 0.762
# a root mean_squared_error: 4.544
# a mean_absolute_error: 3.624
# **spatial scale: c
# c r2_score: 0.753
# c root mean_squared_error: 4.628
# c mean_absolute_error: 3.691
# === monthly ===
# #########
# ##gas_flag: _gas
# **spatial scale: r
# r r2_score: 0.84
# r root mean_squared_error: 3.729
# r mean_absolute_error: 2.956
# **spatial scale: a
# a r2_score: 0.887
# a root mean_squared_error: 3.135
# a mean_absolute_error: 2.408
# **spatial scale: c
# c r2_score: 0.862
# c root mean_squared_error: 3.461
# c mean_absolute_error: 2.793
# ##gas_flag:
# **spatial scale: r
# r r2_score: 0.797
# r root mean_squared_error: 4.198
# r mean_absolute_error: 3.243
# **spatial scale: a
# a r2_score: 0.85
# a root mean_squared_error: 3.612
# a mean_absolute_error: 2.836
# **spatial scale: c
# c r2_score: 0.85
# c root mean_squared_error: 3.612
# c mean_absolute_error: 2.865
# ============================

# %%
dd = {
    "loc":loc_ls,
    "time_scale":time_scale_ls,
    "spatial_scale":spatial_scale_ls,
    "gas":gas_ls,
    "r2":r2_ls,
    "rmse":rmse_ls,
    "mae":mae_ls
}

df = pd.DataFrame(dd)
df.to_csv("./data/apply_model.csv",index=False)

# %% [markdown]
# ## visualization

# %%
df = pd.read_csv("./data/apply_model.csv")
